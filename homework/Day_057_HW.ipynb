# %% [markdown]
# # 作業
# - 作業目標 : 用 iris (dataset.load_iris()) 資料嘗試跑 hierarchical clustering

# %%
from sklearn import datasets
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

iris = datasets.load_iris()
X = iris.data
y = iris.target

# %% [markdown]
# 載入 相關套件 並 執行 hierarchical clustering 實驗 ...

# %% [markdown]
# ## 凝聚分層分群&階層樹狀圖 by Scipy

# %%
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram

plt.figure(figsize=(8, 5))
linkage_matrix = linkage(X , "ward")

# p: 集群數
# truncate_mode: 階層樹太大可讀性低，因此可以利用此參數裁剪
# show_leaf_counts: 顯示leaf分群數量
tree = dendrogram(linkage_matrix , p = 3 , truncate_mode = 'lastp' , show_leaf_counts = True)

plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
aggc_ward = AgglomerativeClustering(linkage = 'ward' , n_clusters = 3)
aggc_complete = AgglomerativeClustering(linkage = 'complete' , n_clusters = 3)
aggc_average = AgglomerativeClustering(linkage = 'average' , n_clusters = 3)

# %%
y_pred_ward = aggc_ward.fit_predict(X)

fignum = 1
fig = plt.figure(fignum, figsize=(4, 3))
ax = Axes3D(fig , rect=[0, 0, 2 ,2.5], elev = 48 , azim = 134)
ax.scatter(X[y_pred_ward == 0, 0], X[y_pred_ward == 0, 1], X[y_pred_ward == 0, 2], s = 100, c = 'red', label = 'Careful')
ax.scatter(X[y_pred_ward == 1, 0], X[y_pred_ward == 1, 1], X[y_pred_ward == 1, 2], s = 100, c = 'blue', label = 'Standard')
ax.scatter(X[y_pred_ward == 2, 0], X[y_pred_ward == 2, 1], X[y_pred_ward == 2, 2], s = 100, c = 'green', label = 'Target')

cluster0_avg = X[y_pred_ward == 0].mean(axis = 0)
cluster1_avg = X[y_pred_ward == 1].mean(axis = 0)
cluster2_avg = X[y_pred_ward == 2].mean(axis = 0)
cluster_avg = np.vstack([cluster0_avg , cluster1_avg , cluster2_avg])

ax.scatter(cluster_avg[: , 0] , cluster_avg[:, 1] , cluster_avg[:, 2], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of iris')
plt.xlabel('feature_0')
plt.ylabel('feature_1')
plt.legend()
plt.show()

# %%
y_pred_complete = aggc_complete.fit_predict(X)

fignum = 1
fig = plt.figure(fignum, figsize=(4, 3))
ax = Axes3D(fig , rect=[0, 0, 2 ,2.5], elev = 48 , azim = 134)
ax.scatter(X[y_pred_complete == 0, 0], X[y_pred_complete == 0, 1], X[y_pred_complete == 0, 2], s = 100, c = 'red', label = 'Careful')
ax.scatter(X[y_pred_complete == 1, 0], X[y_pred_complete == 1, 1], X[y_pred_complete == 1, 2], s = 100, c = 'blue', label = 'Standard')
ax.scatter(X[y_pred_complete == 2, 0], X[y_pred_complete == 2, 1], X[y_pred_complete == 2, 2], s = 100, c = 'green', label = 'Target')

cluster0_avg = X[y_pred_complete == 0].mean(axis = 0)
cluster1_avg = X[y_pred_complete == 1].mean(axis = 0)
cluster2_avg = X[y_pred_complete == 2].mean(axis = 0)
cluster_avg = np.vstack([cluster0_avg , cluster1_avg , cluster2_avg])

ax.scatter(cluster_avg[: , 0] , cluster_avg[:, 1] , cluster_avg[:, 2], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of iris')
plt.xlabel('feature_0')
plt.ylabel('feature_1')
plt.legend()
plt.show()

# %%
y_pred_average = aggc_average.fit_predict(X)

fignum = 1
fig = plt.figure(fignum, figsize=(4, 3))
ax = Axes3D(fig , rect=[0, 0, 2 ,2.5], elev = 48 , azim = 134)
ax.scatter(X[y_pred_average == 0, 0], X[y_pred_average == 0, 1], X[y_pred_average == 0, 2], s = 100, c = 'red', label = 'Careful')
ax.scatter(X[y_pred_average == 1, 0], X[y_pred_average == 1, 1], X[y_pred_average == 1, 2], s = 100, c = 'blue', label = 'Standard')
ax.scatter(X[y_pred_average == 2, 0], X[y_pred_average == 2, 1], X[y_pred_average == 2, 2], s = 100, c = 'green', label = 'Target')

cluster0_avg = X[y_pred_average == 0].mean(axis = 0)
cluster1_avg = X[y_pred_average == 1].mean(axis = 0)
cluster2_avg = X[y_pred_average == 2].mean(axis = 0)
cluster_avg = np.vstack([cluster0_avg , cluster1_avg , cluster2_avg])

ax.scatter(cluster_avg[: , 0] , cluster_avg[:, 1] , cluster_avg[:, 2], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of iris')
plt.xlabel('feature_0')
plt.ylabel('feature_1')
plt.legend()
plt.show()
